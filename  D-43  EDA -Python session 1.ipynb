# %%
##################################################
****************EDA*******************************
1) pandas: dataframe analysis
    
2) Numpy: numericAl python/Number python
    
3) matplotlib: plot
    
4) seaborn: plot
    
5) plotly: plot
    
6) bokhe: plot
    
*****************************ML********************
7) scikit-learn: sklearn
    
****************************DL*********************
8) tensorflow
9) keras
10) pytorch
11) cv : computer vision
    
 *******************************************NLP*********************
12) NLTK
13) scipy

*****************************************Generative AI**************

14) ChatGPT: openAI
15) makersuit: google generative AI
16) Amazon Q

***********************************Hugging face transformer (BERT) ******************
17) Transformers

*************************************other********************************************

random
math
os
sys
time

*************************************** Azure ML **************************************

Azure packages
Gcp vertex  AI
Aws sage maker

# %% [markdown]
# # step-1
# ## import required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # step-2
#
# ## Read the data
#
# ## Visadataset

# %%
# file location 
# file name
# extention
file_path="C:\\Users\sony\\ DATA SCIENCE  NARESH IT\\Visadataset.csv"

pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Isd_math_score_data

# %%
file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\lsd_math_score_data.csv"

pd.read_csv(file_path,sep=';')
# Out:
#   Time_delay,Drug_ppm,Math_score
# 0                   5,1.17,78.93
# 1                   15,2.97,58.2
# 2                  30,3.26,67.47
# 3                  60,4.69,37.47
# 4                 120,5.83,45.65
# 5                    240,6,32.92
# 6                 480,6.41,29.97

# %% [markdown]
# # step-3
#
# ## Create a dataframe using lists

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]

pd.DataFrame(zip(list1,list2),columns=['Name','Age'])
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]
cols=['Name','age']

pd.DataFrame(zip(list1,list2),columns=cols)
# Out:
#      Name  age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]
cols=['Name','age']

names=pd.DataFrame(zip(list1,list2),columns=cols)

# %%
names
# Out:
#      Name  age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# # Step-4
#
# ## How to save the dataframe in local

# %%
# what is your dataframe name: names
# where you want to save: C:\Users\sony\ DATA SCIENCE  NARESH IT
# what name you want to provide : NAMES

names.to_csv("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\NAMES.csv")

# %%
names.to_csv("NAMES.csv")

# this will save where our python file located

# %%
names.to_csv("NAMES1.csv",index=False)

# it will not create extra column as index

# %% [markdown]
# # task-1
#
# ## read NAMES and NAMES1

# %%
filepath1="NAMES.csv"
pd.read_csv(filepath1)

# how can we avoid unnamed 0
# Out:
#    Unnamed: 0    Name  age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
filepath2="NAMES1.csv"
pd.read_csv(filepath2)
# Out:
#      Name  age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# # Step-5
#
# ## add a new column to existing dataframe

# %%
names
# what is your data frame name : names
# what is the name of the column you want add : city
# how many rows we have in original data : 3
# what is your new data = ['Hyd','Chennai','Blr']
# Out:
#      Name  age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
names['city']=['Hyd','Chennai','Blr']

# %%
names
# Out:
#      Name  age     city
# 0     Ram   30      Hyd
# 1  Raheem   31  Chennai
# 2  Robert   32      Blr

# %%
# Length of values (4) does not match length of index (3)
# names['id']=[1,2,3,4]

# %%
# what is your data frame name : name
********************axis*************************
# I want to drop column
# axies=1 ============ columns
# axies=0 ============ rows
**********************************************
# what is the name of the column : city
******************inplace**********************
# when you are drop the column means
# you are modifying the table
# the dataframe overwrite or
# you want to create a dataframe

# inplace=true : data will be overwrite

# %%
names.drop('city',
           axis=1,
           inplace=True)

# %%
names
# Out:
#      Name  age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# - we are changing these thinks in main Dataframe 'names'
# - so it will reflect in local Dataframe "NAME" orwe need to save it every time?
