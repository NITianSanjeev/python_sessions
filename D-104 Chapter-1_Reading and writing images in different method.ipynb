# %%
import cv2

# first import the package:
# if you get the error: then install the package

# !pip install opencv-python

# when you want install through cmd: remove ! mark
#                                  : pip instal <package_name>

# if you want install in Jupyter notebook: add the ! mark and run 
#                                        : !pip install <package_name>

# %% [markdown]
# ## Method-1

# %% [markdown]
# - Using the openCV method
#
# - When you read image , it will open a new window
#
# - And image will display on the window
#
# - if you want to close the window press:0

# %%
import os
os.getcwd()

# './images/Benjamin-Franklin.jpg' # Related path

# r'C:\Users\sony\ DATA SCIENCE  NARESH IT\Benjamin-Franklin.jpg
# Out:
# 'C:\\Users\\sony\\ DATA SCIENCE  NARESH IT'

# %%
import cv2
image=cv2.imread("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
image.shape
# Out:
# (194, 203, 3)

# %%
image[0][0]
# Out:
# array([23, 25, 25], dtype=uint8)

# %%
# All together in local=================
import cv2
image=cv2.imread("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
#input1 = cv2.imread('./image/Benjamin-Franklin.webp')
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Method-2
#
# - using google colab notebool
# - Run below codes in google colab only

# %%
#================ In google colab=======================
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread("contents/Benjamin-Franklin.jpg")
cv2_imshow(image)

# %% [markdown]
# ## Method-3
#
# - Using Pillow package

# %%
#=========================== by using Pillow it will open the another window==================
from PIL import Image
image = Image.open("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
image.show()  # open the new window

# %%
#=========================== remove the show and it will open in some notebook=========
from PIL import Image
image = Image.open("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
image #open in jupyter notebook
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=203x194 at 0x17E24D80FA0>

# %% [markdown]
# ## Method-4
#
# - Open using matplotlib

# %%
#================================== Read the image using pillow and open the image using matplotlib
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %%
#============================== Read the image using Pillow and open By using matplotlib============
import  matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow    
image = Image.open("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)


#============================================ Read the image using Pillow and open the image
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
#open the image using matplotlib
plt.imshow(image)

# %% [markdown]
# ## Writing images

# %%
import cv2
image=cv2.imread("C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Benjamin-Franklin.jpg")
cv2.imwrite('output.jpg', image)
cv2.imwrite('output.png', image)
# Out:
# True
