# %% [markdown]
# - In every data set we have different columnns has different units
#
# - In every dataset we have different columns has values varies from -inf to inf
#
# - It is very important standardize the data,make sure all the column values under same range
#
# - To archive this we have two methods
#
#      - Normalization
#      - standardization

# %% [markdown]
# ## Normalization:
#
#          - min max scalar
#
#
# <img id="dimg_Wvm6Z8bhBuWS1e8Pt5eoiAo_27" src="data:image/png;base64,..." class="YQ4gaf" height="127" style="object-position:40% 33%" width="397" alt="Data normalization formula. | Download ..." data-csiid="Wvm6Z8bhBuWS1e8Pt5eoiAo_16" data-atf="1">

# %% [markdown]
# ## Standardization:
#
#      - Z-score
#
#
# <img id="dimg_Wvm6Z8bhBuWS1e8Pt5eoiAo_11" src="data:image/png;base64,..." class="YQ4gaf" height="177" style="object-position:33% 45%" width="284" alt="How to normalize data in Excel" data-csiid="Wvm6Z8bhBuWS1e8Pt5eoiAo_37" data-atf="4">

# %%
# import packages
# Read the data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Step-1: calcaulate min value of p_Wage=min_wage

# Step-2: calculate max value of p_wage=max_wage

# Step-3: Dr= max_wage-min_wage

# Step-4: Nr= p_wage-min_wage

# Step-5: Nr/Dr

# %%
###################### Read the data ##################################
file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Visadataset.csv"
visa_df=pd.read_csv(file_path)


min_wage=visa_df['prevailing_wage'].min()
max_wage=visa_df['prevailing_wage'].max()
dr=max_wage-min_wage
nr=visa_df['prevailing_wage']-min_wage
visa_df['prevailing_wage_norm']=nr/dr

# %%
visa_df[['prevailing_wage','prevailing_wage_norm']]
# Out:
#        prevailing_wage  prevailing_wage_norm
# 0             592.2029              0.001849
# 1           83425.6500              0.261345
# 2          122996.8600              0.385312
# 3           83434.0300              0.261371
# 4          149907.3900              0.469616
# ...                ...                   ...
# 25475       77092.5700              0.241505
# 25476      279174.7900              0.874579
# 25477      146298.8500              0.458311
# 25478       86154.7700              0.269895
# 25479       70876.9100              0.222033
#
# [25480 rows x 2 columns]

# %%
visa_df['prevailing_wage_norm'].max(),visa_df['prevailing_wage_norm'].min()
# Out:
# (1.0, 0.0)

# %%
visa_df['prevailing_wage'].max(),visa_df['prevailing_wage'].min()
# Out:
# (319210.27, 2.1367)

# %%
max_id=visa_df['prevailing_wage_norm'].idxmax()
min_id=visa_df['prevailing_wage_norm'].idxmin()
max_id,min_id
# Out:
# (21077, 20575)

# %%
visa_df[['prevailing_wage','prevailing_wage_norm']].iloc[[max_id,min_id]]
# Out:
#        prevailing_wage  prevailing_wage_norm
# 21077      319210.2700                   1.0
# 20575           2.1367                   0.0

# %% [markdown]
# ## MinMax Scalar
#
#     - MinMaxScalar is a method from sklearn preprocessing
#
#     - Read the packages
#
#     - save the package
#
#     - Apply for transform

# %%
####################### Read the data ########################

file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Visadataset.csv"
visa_df=pd.read_csv(file_path)

# Step-1:
from sklearn.preprocessing import MinMaxScaler
# Step-2:
mms=MinMaxScaler()
# Step-3:
visa_df['prevailing_wage_norm1'] = mms.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## Note:
#
#     -Inside MinMaxScalar pass dataframe not series

# %%
# array
v1=np.array([[1,2,3,4]])
v1.ndim
# Out:
# 2

# %% [markdown]
# ## Z-score

# %%
# Step-1: calculate the mean
# Step-2: calculate std
# Step-3: Nr= x-mean
# Step-4: Nr/std

mean_wage=visa_df['prevailing_wage'].mean()
std_wage=visa_df['prevailing_wage'].std()
nr=visa_df['prevailing_wage']-mean_wage
visa_df['prevailing_wage_zscore']=nr/std_wage

# %%
visa_df[['prevailing_wage','prevailing_wage_zscore']]
# Out:
#        prevailing_wage  prevailing_wage_zscore
# 0             592.2029               -1.398510
# 1           83425.6500                0.169832
# 2          122996.8600                0.919060
# 3           83434.0300                0.169991
# 4          149907.3900                1.428576
# ...                ...                     ...
# 25475       77092.5700                0.049923
# 25476      279174.7900                3.876083
# 25477      146298.8500                1.360253
# 25478       86154.7700                0.221504
# 25479       70876.9100               -0.067762
#
# [25480 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.boxplot(visa_df['prevailing_wage'])
plt.subplot(1,2,2)
plt.boxplot(visa_df['prevailing_wage_zscore'])
plt.show()

# %% [markdown]
# ## StandardScalar

# %%
from sklearn.preprocessing import StandardScalar
ss=StandardScaler()
Ss.fit_transform(visa_df[['prevailing_wage']])
