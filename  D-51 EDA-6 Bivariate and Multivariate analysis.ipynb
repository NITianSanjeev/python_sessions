# %% [markdown]
# # This is completed
#
# - EDA session-1:
#
#       - Read the data
#
#       - create the data frame using list
#
#       - How to save the data frame
#
#       - how to drop the column
#
# - EDA session-2:
#
#        - shape/size
#
#        - column/dtype
#
#        - head/tail
#
#        - take/loc/iloc
#
#        - isnull/len
#
# - EDA session-3: Categorical data analysis
#
#        - How to read a column
#
#        - unique/nunique
#
#        - we created a frequency table by our own skill
#
#        - bar chart
#
#        - pie chart
#
# - EDA session-4: Numerical data analysis
#
#        - How to read a column
#
#        - statistical measurements
#
#        - mean/meadian/count/max/min/std/25/50/75
#
#        - describe function
#
#        - using numpy we draw measurments
#
#        - Histrogram
#
#        - we checked the emirical rule
#
# - EDA session-5: outlier analysis
#
#         - we draw box plot
#
#         - we implemented how to find outlier
#
#         - we remove the outliers
#
#         - we imputed with median
#
#         - np.where
#
# - EDA session-6: Bi variate and multivariate analysis
#
#         - we draw two cat columns analysis
#
#         - we implemented by own skill
#
#         - pd.crosstab
#
#         - draw the plots
#
#         - we repeated multiple columns
#
#         - for two numerica columns plt.scatter
#
#         - correlation data.corr
#
#         - matrix
#
#         - heatmap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# corr function
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
# Matrix
# showing value in a matrix
# showing value in a picture: Heatmap

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
# Out:
# <AxesSubplot:>

# %%
# winequality dataset

file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\winequality_red.csv"
wine_df=pd.read_csv(file_path)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(wine_df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(wine_df['fixed acidity'],wine_df['citric acid'])

# %%
plt.scatter(wine_df['fixed acidity'],wine_df['pH'])

# %%
file_path="C:\\Users\\sony\\ DATA SCIENCE  NARESH IT\\winequality_red.csv"
wine_df=pd.read_csv(file_path)
wine_df

wine_df.corr()

plt.figure(figsize=(10,10))
sns.heatmap(wine_df.corr(),annot=True)


plt.scatter(wine_df['fixed acidity'],wine_df['citric acid'])
