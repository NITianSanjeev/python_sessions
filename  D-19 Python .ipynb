# %% [markdown]
# ## Local variables :
#
# ### The variables inside the function

# %% [markdown]
# ## Global variables :
#
# ### The variables provided outside the functons

# %% [markdown]
# ## Local variables:

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))

# %% [markdown]
# ## Global variables:

# %%
n1=20
n2=30
def addition():     # No need to provide inside the bracket
    # No need to mention
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()
# Out:
# the addition of 20 and 30 is 50

# %%
def avg():    # This is local variable
    num1=20
    num2=30
    num3=40
    avg=(num1+num2+num3)/3
    print("the average of {} , {} and {}is {}".format(num1,num2,num3,avg))
    
avg()
# Out:
# the average of 20 , 30 and 40is 30.0

# %%
num1=20             # This is global variabl  
num2=30
num3=40
def avg():         
    avg=(num1+num2+num3)/3
    print("the average of {} , {} and {}is {}".format(num1,num2,num3,avg))
    
avg()
# Out:
# the average of 20 , 30 and 40is 30.0

# %%
def avg():    # This is local variable
    num11=20
    num22=30
    num33=40
    avg=(num1+num2+num3)/3
    print("the average of {} , {} and {}is {}".format(num1,num2,num3,avg))
    return(num11)
    
avg()
# Out:
# the average of 20 , 30 and 40is 30.0
# 20

# %%
val1
# Out:
# 20

# %%
def avg():
    num11=20             
    num22=30
    num33=40
    avg=(num1+num2+num3)/3
    print("the average of {} , {} and {}is {}".format(num1,num2,num3,avg))
    return(num11,num22)
val1,val2=avg()
# Out:
# the average of 20 , 30 and 40is 30.0

# %%
val2
# Out:
# 30

# %% [markdown]
# ### local variable are inside the function
#
# ### local variable values can not use to outside the function
#
# ### until unless you return those values

# %%
num11=20             # This is global variabl  
num22=30
num33=40
def avg():         
    avg=(num1+num2+num3)/3
    print("the average of {} , {} and {}is {}".format(num11,num22,num33,avg))
    
avg() 

print(num11*num22)
# Out:
# the average of 20 , 30 and 40is 30.0
# 600

# %%
num11
# Out:
# 20

# %%
n1=20
n2=30
def addition():
    n1=200
    n2=300
    add=n1+n2
    print(" The addition of {} and {} is {}".format(n1,n2,add))
    
addition() 

print(n1)
# Out:
#  The addition of 200 and 300 is 500
# 20

# %%
n1=20
n2=30
def addition(n1):
    n2=300
    add=n1+n2
    print(" The addition of {} and {} is {}".format(n1,n2,add))
    
addition(500) 
print(n1)
# Out:
#  The addition of 500 and 300 is 800
# 20

# %%
n1=20
n2=30
def addition(n1=700):
    n2=300
    add=n1+n2
    print(" The addition of {} and {} is {}".format(n1,n2,add))
    
addition(500) 
print(n1)
# Out:
#  The addition of 500 and 300 is 800
# 20

# %%
# we can not use local variable values outside the function
# until unless with out return the function

# i want to use local variable outside the function , with out using return statemant

# %%
global

# %%
n1=10
def updated():
    n1=n1+100
    print("n1 value inside the function is :",n1)
    
updated()  #110
print(n1)  #10

# without return n1 ,we need to get updated value
# we need to use local variable outside the function,without return
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [35], in <cell line: 6>()
#       3     n1=n1+100
#       4     print("n1 value inside the function is :",n1)
# ----> 6 updated()  #110
#       7 print(n1)
#
# Input In [35], in updated()
#       2 def updated():
# ----> 3     n1=n1+100
#       4     print("n1 value inside the function is :",n1)
#
# UnboundLocalError: local variable 'n1' referenced before assignment

# %%
def value():
    global number1,number2
    number1=10
    number2=20
    print(number1)
    
value() 
print(number1)
print(number2)
# Out:
# 10
# 10
# 20

# %%
n_=10
def updated():
    global n_
    n_=20
    n_=n_+100
    print("the value inside function is:",n_)
    
updated()  
print(n_)
# Out:
# the value inside function is: 120
# 120

# %%
n1=20
n2=30
def addition(n1):
    global n2,add
    n2=300
    add=n1+n2
    print("the action of {} and {} is {}".format(n1,n2,add))
    
addition(500) 

print(n2)
print(add)
# Out:
# the action of 500 and 300 is 800
# 300
# 800

# %% [markdown]
# ## Function in function

# %%
def greet():
    print("hello")
    
def name():
    print("python")
    
greet() 
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
    
def name():
    print('python')
    greet()
    
name()
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    
def name():
    print('python')
    
greet()
# Out:
# hello

# %%
def greet():
    print("hello")
    name()
    
def name():
    print('python')
    greet()
    
greet() 
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
print(3)

def fun1():
    print('hello')
    print('python')
    
print('10+10')
def fun2():
    print('3+5')
    print(3+5)
    fun1()
    print('good')
    
print(10+10)
def fun3():
    fun1()
    fun2()
    
fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
# create a four function
# def add(a+b):
# print(a+b)
# sub
# mul
# div

# def main():
     # you need to provide some print statemant
     # if you want to enter 1   :addition operation will come
     # if you want to enter 2   :subtract
     # if you enter 3 : mul
     # if you enter 4 : div
     # operation=input("enter a number")
     # a=eval(input())   
     # b=eval(input())
     # if operation=='1':
     #      add(a,b)
     # if operation=='2':
     #      sub(a,b)
     # if operation=='3':
     #      mul(a,b)
     # if operation=='4':
     #      div(a,b)

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def div(a,b):
    print(a/b)
def mul(a,b): 
    print(a*b)
    
def main():
    num=eval(input("enter a number: "))
    a=eval(input("enter a number1: "))
    b=eval(input("enter a number2: "))
    if num==1:
        add(a,b)
    elif num==2:
        sub(a,b)
    elif num==3:
        div(a,b)
    else:
        mul(a,b)
        
main()
# Out:
# enter a number: 10
# enter a number1: 20
# enter a number2: 30
# 600
